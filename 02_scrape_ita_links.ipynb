# %%
import pandas as pd
from scraper.scrape import fetch_html_for_urls
import bs4 as bs

# %%
data = pd.read_csv('data/unctad_clean.csv')

# %%
data = fetch_html_for_urls(data, url_col='link_to_italaws_case_page', html_col='italaw_html')
# Out:
# Fetching HTML:   1%|          | 8/1332 [00:00<01:57, 11.29it/s]
# Failed to fetch https://www.italaw.com/cases/9081: 403 Client Error: Forbidden for url: https://www.italaw.com/cases/9081
# Fetching HTML:  27%|██▋       | 353/1332 [00:33<01:49,  8.97it/s]
# Failed to fetch https://www.italaw.com/cases/9419: 404 Client Error: Not Found for url: https://www.italaw.com/cases/9419
# Fetching HTML:  47%|████▋     | 629/1332 [01:14<02:07,  5.53it/s]
# Failed to fetch http://www.italaw.com/cases/4721: 403 Client Error: Forbidden for url: https://www.italaw.com/cases/4721
# Fetching HTML:  67%|██████▋   | 887/1332 [02:24<01:37,  4.57it/s]
# Failed to fetch http://www.italaw.com/cases/2836: 404 Client Error: Not Found for url: https://www.italaw.com/cases/2836
# Fetching HTML:  69%|██████▉   | 916/1332 [02:33<02:39,  2.62it/s]
# Failed to fetch http://www.italaw.com/cases/2119: 404 Client Error: Not Found for url: https://www.italaw.com/cases/2119
# ...

# %%
data.to_csv('data/unctad_clean_with_html.csv', index=False)
